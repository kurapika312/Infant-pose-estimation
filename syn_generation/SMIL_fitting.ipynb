# %%
import os
import cv2
from matplotlib import pyplot as plt
os.getcwd()
# Out:
# '/media/Data/ETS-Projects/Current-work/Infant-Pose-Estimation/syn_generation'

# %%
# %run smplifyx/main.py \
   --config cfg_files/fit_smil.yaml \
   --data_folder data \
   --output_folder output \
   --visualize=False \
   --model_folder models

# %%
# %cd output/images
img_orig = cv2.imread('data/images/2000.jpg')
img_mesh = cv2.imread('output/images/2000/000/output.png')
plt.subplot(1,2,1)
plt.imshow(img_orig)
plt.subplot(1,2,2)
plt.imshow(img_mesh)
plt.show()
